# %% [markdown]
# # UNSW-NB15 Cybersecurity Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('D:\\IIT Kharagpur Notes\\Semester IV\\Datasets\\UNSW-NB15 - CSV Files\\UNSW-NB15 - CSV Files\\a part of training and testing set\\UNSW_NB15_training-set.csv')

# %%
df.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0   1  0.000011   udp       -   INT      2      0     496       0
# 1   2  0.000008   udp       -   INT      2      0    1762       0
# 2   3  0.000005   udp       -   INT      2      0    1068       0
# 3   4  0.000006   udp       -   INT      2      0     900       0
# 4   5  0.000010   udp       -   INT      2      0    2126       0
#
#           rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0   90909.0902  ...                 1               2             0
# 1  125000.0003  ...                 1               2             0
# 2  200000.0051  ...                 1               3             0
# 3  166666.6608  ...                 1               3             0
# 4  100000.0025  ...                 1               3             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0           0                 0           1           2                0
# ...

# %%
df.tail()
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 82327  82328  0.000005   udp       -   INT      2      0     104       0
# 82328  82329  1.106101   tcp       -   FIN     20      8   18062     354
# 82329  82330  0.000000   arp       -   INT      1      0      46       0
# 82330  82331  0.000000   arp       -   INT      1      0      46       0
# 82331  82332  0.000009   udp       -   INT      2      0     104       0
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 82327  200000.005100  ...                 1               2             0
# 82328      24.410067  ...                 1               1             0
# 82329       0.000000  ...                 1               1             0
# 82330       0.000000  ...                 1               1             0
# 82331  111111.107200  ...                 1               1             0
#
#        ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# ...

# %%
df
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011   udp       -   INT      2      0     496       0
# 1          2  0.000008   udp       -   INT      2      0    1762       0
# 2          3  0.000005   udp       -   INT      2      0    1068       0
# 3          4  0.000006   udp       -   INT      2      0     900       0
# 4          5  0.000010   udp       -   INT      2      0    2126       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 82327  82328  0.000005   udp       -   INT      2      0     104       0
# 82328  82329  1.106101   tcp       -   FIN     20      8   18062     354
# 82329  82330  0.000000   arp       -   INT      1      0      46       0
# 82330  82331  0.000000   arp       -   INT      1      0      46       0
# 82331  82332  0.000009   udp       -   INT      2      0     104       0
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82332 entries, 0 to 82331
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 82332 non-null  int64
#  1   dur                82332 non-null  float64
#  2   proto              82332 non-null  object
#  3   service            82332 non-null  object
#  4   state              82332 non-null  object
#  5   spkts              82332 non-null  int64
#  6   dpkts              82332 non-null  int64
#  7   sbytes             82332 non-null  int64
#  8   dbytes             82332 non-null  int64
#  9   rate               82332 non-null  float64
#  10  sttl               82332 non-null  int64
#  11  dttl               82332 non-null  int64
#  12  sload              82332 non-null  float64
#  13  dload              82332 non-null  float64
#  14  sloss              82332 non-null  int64
#  15  dloss              82332 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id           dur         spkts         dpkts        sbytes  \
# count  82332.000000  82332.000000  82332.000000  82332.000000  8.233200e+04
# mean   41166.500000      1.006756     18.666472     17.545936  7.993908e+03
# std    23767.345519      4.710444    133.916353    115.574086  1.716423e+05
# min        1.000000      0.000000      1.000000      0.000000  2.400000e+01
# 25%    20583.750000      0.000008      2.000000      0.000000  1.140000e+02
# 50%    41166.500000      0.014138      6.000000      2.000000  5.340000e+02
# 75%    61749.250000      0.719360     12.000000     10.000000  1.280000e+03
# max    82332.000000     59.999989  10646.000000  11018.000000  1.435577e+07
#
#              dbytes          rate          sttl          dttl         sload  \
# count  8.233200e+04  8.233200e+04  82332.000000  82332.000000  8.233200e+04
# mean   1.323379e+04  8.241089e+04    180.967667     95.713003  6.454902e+07
# ...

# %%
df.describe().transpose()
# Out:
#                      count          mean           std   min           25%  \
# id                 82332.0  4.116650e+04  2.376735e+04   1.0  20583.750000
# dur                82332.0  1.006756e+00  4.710444e+00   0.0      0.000008
# spkts              82332.0  1.866647e+01  1.339164e+02   1.0      2.000000
# dpkts              82332.0  1.754594e+01  1.155741e+02   0.0      0.000000
# sbytes             82332.0  7.993908e+03  1.716423e+05  24.0    114.000000
# dbytes             82332.0  1.323379e+04  1.514715e+05   0.0      0.000000
# rate               82332.0  8.241089e+04  1.486204e+05   0.0     28.606114
# sttl               82332.0  1.809677e+02  1.015134e+02   0.0     62.000000
# dttl               82332.0  9.571300e+01  1.166677e+02   0.0      0.000000
# sload              82332.0  6.454902e+07  1.798618e+08   0.0  11202.466797
# dload              82332.0  6.305470e+05  2.393001e+06   0.0      0.000000
# ...

# %%
df.corr()
# Out:
#                          id       dur     spkts     dpkts    sbytes    dbytes  \
# id                 1.000000  0.016037 -0.020766 -0.037020 -0.005647 -0.031115
# dur                0.016037  1.000000  0.280239  0.217507  0.225432  0.172492
# spkts             -0.020766  0.280239  1.000000  0.369554  0.965750  0.198324
# dpkts             -0.037020  0.217507  0.369554  1.000000  0.175834  0.976419
# sbytes            -0.005647  0.225432  0.965750  0.175834  1.000000  0.010036
# dbytes            -0.031115  0.172492  0.198324  0.976419  0.010036  1.000000
# rate              -0.121700 -0.118031 -0.068249 -0.083173 -0.025102 -0.047978
# sttl               0.095939 -0.000986 -0.092536 -0.163830 -0.017866 -0.114537
# dttl               0.306539  0.090048  0.054601  0.036483  0.049891  0.012537
# sload             -0.003063 -0.076343 -0.044194 -0.054145 -0.015228 -0.031266
# dload             -0.106562 -0.047032  0.074440  0.133835 -0.006428  0.100923
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 82327    False
# 82328    False
# 82329    False
# 82330    False
# 82331    False
# Length: 82332, dtype: bool

# %%
df.drop_duplicates()
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011   udp       -   INT      2      0     496       0
# 1          2  0.000008   udp       -   INT      2      0    1762       0
# 2          3  0.000005   udp       -   INT      2      0    1068       0
# 3          4  0.000006   udp       -   INT      2      0     900       0
# 4          5  0.000010   udp       -   INT      2      0    2126       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 82327  82328  0.000005   udp       -   INT      2      0     104       0
# 82328  82329  1.106101   tcp       -   FIN     20      8   18062     354
# 82329  82330  0.000000   arp       -   INT      1      0      46       0
# 82330  82331  0.000000   arp       -   INT      1      0      46       0
# 82331  82332  0.000009   udp       -   INT      2      0     104       0
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82332 entries, 0 to 82331
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 82332 non-null  int64
#  1   dur                82332 non-null  float64
#  2   proto              82332 non-null  object
#  3   service            82332 non-null  object
#  4   state              82332 non-null  object
#  5   spkts              82332 non-null  int64
#  6   dpkts              82332 non-null  int64
#  7   sbytes             82332 non-null  int64
#  8   dbytes             82332 non-null  int64
#  9   rate               82332 non-null  float64
#  10  sttl               82332 non-null  int64
#  11  dttl               82332 non-null  int64
#  12  sload              82332 non-null  float64
#  13  dload              82332 non-null  float64
#  14  sloss              82332 non-null  int64
#  15  dloss              82332 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes',
#        'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss',
#        'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin',
#        'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth',
#        'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm',
#        'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm',
#        'ct_srv_dst', 'is_sm_ips_ports', 'attack_cat', 'label'],
#       dtype='object')

# %%
# Rename columns to be more descriptive
df.columns = ['id', 'dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes','dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss','sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin','tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth','response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm','ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm','is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm','ct_srv_dst', 'is_sm_ips_ports', 'attack_cat', 'label']

# Group vulnerabilities by attack category and count them
attacks = df.groupby("attack_cat")["attack_cat"].count().sort_values(ascending=False)

# Get the 10 most common attacks
top_attacks = attacks.head(10)

# Calculate the cumulative sum of attacks
cumulative_sum = top_attacks.cumsum()

# Calculate the percentage of total attacks
total_attacks = attacks.sum()
percentages = (top_attacks / total_attacks) * 100

# Create a Pareto chart using Matplotlib
fig, ax1 = plt.subplots()

ax1.bar(top_attacks.index, top_attacks, color="b")
ax1.set_xlabel("Attack Types")
ax1.set_ylabel("Frequency", color="b")
ax1.tick_params(axis="y", labelcolor="b")

ax2 = ax1.twinx()
ax2.plot(percentages, color="r", marker="D", ms=7)
ax2.axhline(y=80, color="black", linestyle="--")
ax2.set_ylabel("Percentage of Total Attacks", color="r")
ax2.tick_params(axis="y", labelcolor="r")

plt.title("Pareto Chart of Important Cybersecurity Vulnerabilities")
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)
    
plt.show()
